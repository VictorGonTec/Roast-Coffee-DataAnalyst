# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline
pd.set_option('display.max_columns',None)

# %%
coffee_data = pd.read_csv('coffee_df_analisis.csv')
coffee_data.head()
# Out:
#                 Location                                          origin  \
# 0     Madison, Wisconsin            Piendamó, Cauca Department, Colombia
# 1  San Diego, California  Trujillo, Valle del Cauca Department, Colombia
# 2   Glendale, California   Yirgacheffe growing region, southern Ethiopia
# 3   Glendale, California                                Tolima, Colombia
# 4    Redding, California           Volcan growing region, western Pa$0ma
#
#           roast  price      weight agtron  aroma  acid  body  flavor  \
# 0  Medium-Light    25.0   8 ounces  59/81    9.0   9.0   9.0     9.0
# 1         Light    59.0   8 ounces  62/80    9.0   9.0   9.0     9.0
# 2  Medium-Light    20.5  12 ounces  60/77    9.0   9.0   9.0     9.0
# 3  Medium-Light    20.5  12 ounces  59/79    9.0   9.0   8.0     9.0
# 4         Light    45.0   4 ounces  62/80    9.0   9.0   9.0     9.0
#
#    aftertaste  with_milk                                             desc_1  \
# ...

# %%
coffee_data.tail()
# Out:
#                        Location  \
# 2276  Highland Park, New Jersey
# 2277             Taipei, Taiwan
# 2278      Branford, Connecticut
# 2279      San Diego, California
# 2280     San Rafael, California
#
#                                                  origin         roast  price   \
# 2276                       Biolley, southern Costa Rica  Medium-Light    28.0
# 2277  Kochere, Yirgacheffe growing region, south-cen...         Light   580.0
# 2278  Piedra Candela, Chiriqui Province, far western...  Medium-Light    55.0
# 2279                  Santa A$0 Department, El Salvador  Medium-Light    25.0
# 2280             Boquete growing region, western Pa$0ma  Medium-Light    37.0
#
#          weight agtron  aroma  acid  body  flavor  aftertaste  with_milk  \
# 2276   8 ounces  53/77    9.0   9.0   8.0     9.0         8.0        NaN
# 2277  220 grams  58/86    9.0   9.0   9.0     9.0         8.0        NaN
# 2278  12 ounces  56/80   10.0   9.0   9.0     9.0         9.0        NaN
# ...

# %%
coffee_data.describe()
# Out:
#               price         aroma         acid         body       flavor  \
# count    2281.000000  2255.000000  1956.000000  2279.000000  2279.000000
# mean      290.919193     8.819512     8.490286     8.594998     8.942080
# std      3654.290676     0.487438     0.635206     0.529707     0.445618
# min         0.000000     2.000000     1.000000     5.000000     2.000000
# 25%        17.500000     9.000000     8.000000     8.000000     9.000000
# 50%        22.000000     9.000000     9.000000     9.000000     9.000000
# 75%       160.000000     9.000000     9.000000     9.000000     9.000000
# max    120000.000000    10.000000    10.000000    10.000000    10.000000
#
#         aftertaste   with_milk
# count  2279.000000  349.000000
# mean      8.091707    8.842407
# std       0.553476    0.509486
# min       2.000000    5.000000
# 25%       8.000000    9.000000
# 50%       8.000000    9.000000
# 75%       8.000000    9.000000
# max      10.000000   10.000000

# %%
coffee_data.dtypes
# Out:
# Location       object
# origin         object
# roast          object
# price         float64
# weight         object
# agtron         object
# aroma         float64
# acid          float64
# body          float64
# flavor        float64
# aftertaste    float64
# with_milk     float64
# desc_1         object
# desc_2         object
# desc_3         object
# dtype: object

# %%
coffee_data.columns
# Out:
# Index(['Location', 'origin', 'roast', 'price ', 'weight', 'agtron', 'aroma',
#        'acid', 'body', 'flavor', 'aftertaste', 'with_milk', 'desc_1', 'desc_2',
#        'desc_3'],
#       dtype='object')

# %%
coffee_data.isna().sum()
# Out:
# Location         0
# origin           0
# roast            0
# price            0
# weight           7
# agtron           0
# aroma           26
# acid           325
# body             2
# flavor           2
# aftertaste       2
# with_milk     1932
# desc_1           0
# desc_2           0
# desc_3           2
# dtype: int64

# %%
coffee_data[coffee_data['weight'].isna()]
# Out:
#                     Location  \
# 524            Yilan, Taiwan
# 579         Hong Kong, Chi$0
# 1115         Shanghai, Chi$0
# 1448         Shanghai, Chi$0
# 1576  Minneapolis, Minnesota
# 1684   Branford, Connecticut
# 1883  Ipswich, Massachusetts
#
#                                                  origin         roast  price   \
# 524            Sidama growing region, southern Ethiopia  Medium-Light     0.0
# 579                          Palesti$0, Huila, Colombia  Medium-Light     0.0
# 1115                                   Sidamo, Ethiopia            $0     0.0
# 1448  Guatemala; Colombia; Brazil; Ethiopia; Yun$0n,...        Medium     0.0
# 1576                        Pichincha, northern Ecuador  Medium-Light     0.0
# 1684             Boquete growing region, western Pa$0ma  Medium-Light     0.0
# 1883                              Santa Maria, Colombia  Medium-Light     0.0
#
#      weight agtron  aroma  acid  body  flavor  aftertaste  with_milk  \
# ...

# %%
coffee_data['weight'].fillna(0,inplace=True)

# %%
coffee_data.isna().sum()
# Out:
# Location         0
# origin           0
# roast            0
# price            0
# weight           0
# agtron           0
# aroma           26
# acid           325
# body             2
# flavor           2
# aftertaste       2
# with_milk     1932
# desc_1           0
# desc_2           0
# desc_3           2
# dtype: int64

# %%
coffee_data[coffee_data['roast']=='$0']
# Out:
#                        Location  \
# 260             London, England
# 669        San Jose, California
# 671        San Jose, California
# 682     New Taipei City, Taiwan
# 684         Taipei City, Taiwan
# 703         Taipei City, Taiwan
# 792             London, England
# 818               Yilan, Taiwan
# 819         Spokane, Washington
# 820     New Taipei City, Taiwan
# 821           Chicago, Illinois
# 822        San Jose, California
# 823    Grove City, Pennsylvania
# 824            Denver, Colorado
# 825        Martinez, California
# 826        Kihei, Maui, Hawai’i
# 827      Emeryville, California
# 913        Glendale, California
# 914        Glendale, California
# 956               Austin, Texas
# 1115            Shanghai, Chi$0
# 1194            London, England
# 1389           Denver, Colorado
# 1390  San Francisco, California
# 1391   Grove City, Pennsylvania
# 1392       Carbondale, Colorado
# 1393    Los Angeles, California
# 1394       Martinez, California
# ...

# %%
coffee_data['roast']=coffee_data['roast'].replace('$0','Not Available')

# %%
coffee_data[(coffee_data['Location']=='London, England')&(coffee_data['roast']=='Not Available')]
# Out:
#              Location                                      origin  \
# 260   London, England      Boquete growing region, western Pa$0ma
# 792   London, England      Boquete growing region, western Pa$0ma
# 1194  London, England      Boquete growing region, western Pa$0ma
# 1426  London, England      Boquete growing region, western Pa$0ma
# 1718  London, England  Karongi District, Western Province, Rwanda
# 2055  London, England      Boquete growing region, western Pa$0ma
#
#               roast  price        weight agtron  aroma  acid  body  flavor  \
# 260   Not Available    50.0  10 capsules    0/0    9.0   NaN   9.0     9.0
# 792   Not Available    50.0  10 capsules    0/0    9.0   NaN   9.0     9.0
# 1194  Not Available    45.0  10 capsules    0/0    9.0   NaN   9.0     9.0
# 1426  Not Available    50.0  10 capsules    0/0    9.0   NaN   8.0     9.0
# 1718  Not Available    40.5  10 capsules    0/0    9.0   NaN   8.0     9.0
# ...

# %%
coffee_data[coffee_data['acid'].isna()]
# Out:
#                     Location  \
# 20    Sacramento, California
# 39            Taipei, Taiwan
# 67        Antigua, Guatemala
# 78            Taipei, Taiwan
# 79            Taipei, Taiwan
# ...                      ...
# 2248    Taoyuan City, Taiwan
# 2251       Ramsey, Minnesota
# 2252       Ramsey, Minnesota
# 2263         Chia-Yi, Taiwan
# 2265         Chia-Yi, Taiwan
#
#                                                  origin         roast  \
# 20                             Chimalte$0ngo, Guatemala  Medium-Light
# 39                      Costa Rica; Honduras; Indonesia  Medium-Light
# 67                    Antigua growing region, Guatemala  Medium-Light
# 78    Ethiopia; Guatemala; El Salvador; Pa$0ma; Cost...        Medium
# 79    Guatemala; Nicaragua; Ethiopia; Costa Rica; In...  Medium-Light
# ...                                                 ...           ...
# 2248      Yirgacheffe growing region, southern Ethiopia        Medium
# ...

# %%
coffee_data.loc[(coffee_data['weight']=='8 ounces')&(coffee_data['agtron']=='54/78')&(coffee_data['aroma']==9),'acid']=8
coffee_data[coffee_data['acid'].isna()]
# Out:
#                     Location  \
# 20    Sacramento, California
# 39            Taipei, Taiwan
# 67        Antigua, Guatemala
# 78            Taipei, Taiwan
# 79            Taipei, Taiwan
# ...                      ...
# 2248    Taoyuan City, Taiwan
# 2251       Ramsey, Minnesota
# 2252       Ramsey, Minnesota
# 2263         Chia-Yi, Taiwan
# 2265         Chia-Yi, Taiwan
#
#                                                  origin         roast  \
# 20                             Chimalte$0ngo, Guatemala  Medium-Light
# 39                      Costa Rica; Honduras; Indonesia  Medium-Light
# 67                    Antigua growing region, Guatemala  Medium-Light
# 78    Ethiopia; Guatemala; El Salvador; Pa$0ma; Cost...        Medium
# 79    Guatemala; Nicaragua; Ethiopia; Costa Rica; In...  Medium-Light
# ...                                                 ...           ...
# 2248      Yirgacheffe growing region, southern Ethiopia        Medium
# ...

# %%
coffee_data.rename(columns={'price ':'price'},inplace=True)

# %%
coffee_data['acid'].fillna(8,inplace=True)

# %%
coffee_data.isna().sum()
# Out:
# Location         0
# origin           0
# roast            0
# price            0
# weight           0
# agtron           0
# aroma           26
# acid             0
# body             2
# flavor           2
# aftertaste       2
# with_milk     1932
# desc_1           0
# desc_2           0
# desc_3           2
# dtype: int64

# %%
coffee_data['aroma'].fillna(method='bfill',inplace=True)

# %%
coffee_data.isna().sum()
# Out:
# Location      0
# origin        0
# roast         0
# price         0
# weight        0
# agtron        0
# aroma         0
# acid          0
# body          0
# flavor        0
# aftertaste    0
# with_milk     0
# desc_1        0
# desc_2        0
# desc_3        0
# dtype: int64

# %%
coffee_data[coffee_data['flavor'].isna()]
# Out:
# Empty DataFrame
# Columns: [Location, origin, roast, price , weight, agtron, aroma, acid, body, flavor, aftertaste, with_milk, desc_1, desc_2, desc_3]
# Index: []

# %%
coffee_data['body'].fillna(method='bfill',inplace=True)

# %%
coffee_data['aftertaste'].fillna(8,inplace=True)

# %%
coffee_data['with_milk'].fillna(0,inplace=True)
coffee_data['flavor'].fillna(0,inplace=True)
coffee_data['desc_3'].fillna('Not Available',inplace=True)

# %%
coffee_data.drop(['desc_1','desc_2','desc_3'],axis=1,inplace=True)

# %% [markdown]
# # Data Visualization

# %%
coffee_data.hist(figsize=(20,10))
plt.show()

# %% [markdown]
# ## comparison of roasted coffee and its price

# %%
coffee_data.plot.scatter(x='roast',y='price',figsize=(10,8))
plt.xticks(rotation=45)
plt.show()

# %%
coffee_data.to_csv('coffee_data_cleaned.csv',index=False)
